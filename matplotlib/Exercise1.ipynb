# %% [markdown]
# <a href="https://colab.research.google.com/github/olive-green/data-science/blob/main/matplotlib/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x1_vals = [1,2,3,4]
y1_vals = [1, 4, 9, 16]
(x2_vals, y2_vals) = ([0,1,1.5,7], [1,4,12,16])
(x3_vals, y3_vals) = ([0,1,3,5], [3,4.5,7,18])

# %%
# plt.figsize(10,5)
plt.plot(x1_vals,y1_vals,  x2_vals,y2_vals , x3_vals,y3_vals)
# plt.plot(x2_vals,y2_vals)
# plt.plot(x3_vals,y3_vals)
plt.show()
